# %% [markdown]
# <a href="https://colab.research.google.com/github/shivaam10/OIBSIP/blob/main/Number_guessing_game_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update
# !apt-get install -y openjdk-11-jdk
# !java -version
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,270 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,111 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# %%writefile GuessTheNumber.java
# import java.util.Random;
# import java.util.Scanner;
#
# public class GuessTheNumber {
#     public static void main(String[] args) {
#         Scanner scanner = new Scanner(System.in);
#         Random random = new Random();
#
#         int minRange = 1;
#         int maxRange = 100;
#         int maxAttempts = 10;
#         int totalRounds = 3;
#         int totalScore = 0;
#
#         System.out.println("Welcome to Guess the Number!");
#         System.out.println("Try to guess the number between " + minRange + " and " + maxRange);
#         System.out.println("You have " + maxAttempts + " attempts per round.");
#         System.out.println("Let's play " + totalRounds + " rounds!\n");
#
#         for (int round = 1; round <= totalRounds; round++) {
#             int targetNumber = random.nextInt(maxRange - minRange + 1) + minRange;
#             int attempts = 0;
#             boolean hasWon = false;
#
#             System.out.println("\nRound " + round + " of " + totalRounds);
#             System.out.println("A new number has been generated!");
#
#             while (attempts < maxAttempts) {
#                 System.out.print("Enter your guess (" + (maxAttempts - attempts) + " attempts left): ");
#                 int guess;
#
#                 try {
#                     guess = scanner.nextInt();
#                 } catch (Exception e) {
#                     System.out.println("Please enter a valid number!");
#                     scanner.nextLine(); // Clear invalid input
#                     continue;
#                 }
#
#                 attempts++;
#
#                 if (guess == targetNumber) {
#                     hasWon = true;
#                     int points = calculatePoints(attempts, maxAttempts);
#                     totalScore += points;
#                     System.out.println("Congratulations! You guessed the number in " + attempts + " attempts!");
#                     System.out.println("Points earned this round: " + points);
#                     break;
#                 } else if (guess < targetNumber) {
#                     System.out.println("Too low! Try a higher number.");
#                 } else {
#                     System.out.println("Too high! Try a lower number.");
#                 }
#             }
#
#             if (!hasWon) {
#                 System.out.println("Game Over! You've used all " + maxAttempts + " attempts.");
#                 System.out.println("The number was: " + targetNumber);
#             }
#
#             System.out.println("Current Total Score: " + totalScore);
#         }
#
#         System.out.println("\nGame Complete!");
#         System.out.println("Final Score: " + totalScore);
#         System.out.println("Thanks for playing!");
#         scanner.close();
#     }
#
#     private static int calculatePoints(int attempts, int maxAttempts) {
#         return (maxAttempts - attempts + 1) * 10;
#     }
# }
# Out:
# Writing GuessTheNumber.java

# %%
# !javac GuessTheNumber.java
# !java GuessTheNumber
# Out:
# Welcome to Guess the Number!
# Try to guess the number between 1 and 100
# You have 10 attempts per round.
# Let's play 3 rounds!
#
#
# Round 1 of 3
# A new number has been generated!
# Enter your guess (10 attempts left): 4
# Too low! Try a higher number.
# Enter your guess (9 attempts left): 28
# Too low! Try a higher number.
# Enter your guess (8 attempts left): 56
# Too high! Try a lower number.
# Enter your guess (7 attempts left): 40
# Too low! Try a higher number.
# Enter your guess (6 attempts left): 47
# Too low! Try a higher number.
# Enter your guess (5 attempts left): 50
# Too low! Try a higher number.
# Enter your guess (4 attempts left): 52
# Too low! Try a higher number.
# Enter your guess (3 attempts left): 53
# Congratulations! You guessed the number in 8 attempts!
# Points earned this round: 30
# Current Total Score: 30
#
# Round 2 of 3
# A new number has been generated!
# Enter your guess (10 attempts left):
